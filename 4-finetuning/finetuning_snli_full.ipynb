# %% [markdown]
# # Post-Processing

# %%
# %pip install datasets transformers scikit-learn pandas torch simpletransformers scipy wandb

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
from simpletransformers.classification import (
    ClassificationModel, ClassificationArgs
)
import pandas as pd
import logging
import torch

# %%
# Confirm CUDA is available
cuda_available = torch.cuda.is_available()
cuda_available
# Out:
# True

# %%
ROOT_CSV_PATH = '/home/nli/data'
OUTPUT_PATH = '/home/nli/outputs'

# %%
df_snli_mt_dev = pd.read_csv(os.path.join(ROOT_CSV_PATH, 'df_snli_train.csv'), delimiter=";", encoding='utf-8')
df_snli_mt_eval = pd.read_csv(os.path.join(ROOT_CSV_PATH, 'df_snli_test.csv'), delimiter=";", encoding='utf-8')

# %%
cols_to_drop = df_snli_mt_dev.columns[:2]
cols_to_drop
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0'], dtype='object')

# %%
df_snli_mt_dev.drop(columns=cols_to_drop, axis=1, inplace=True)
df_snli_mt_eval.drop(columns=cols_to_drop, axis=1, inplace=True)

# %%
df_snli_mt_dev.head(5)
# Out:
#                                              premise  \
# 0  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 1  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 2  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 3                 Tfal jitbissmu u jxejru mal-kamera
# 4                 Tfal jitbissmu u jxejru mal-kamera
#
#                                           hypothesis classification
# 0  Persuna qed titħarreġ iż-żiemel tagħha għal ko...        neutral
# 1             Persuna tkun f'diner, tordna omelette.  contradiction
# 2                    Persuna tkun barra, fuq żiemel.     entailment
# 3             Qed jitbissmu lejn il-ġenituri tagħhom        neutral
# 4                                 Hemm tfal preżenti     entailment

# %%
df_snli_mt_dev.columns = ["text_a","text_b","labels"]
df_snli_mt_eval.columns = ["text_a","text_b","labels"]

# %%
def map_to_num(label):
  if label == 'entailment':
    return 0
  elif label == 'contradiction':
    return 2
  else:
    return 1

def map_to_label(num):
  if num == 0:
    return "entailment"
  elif num == 2:
    return "contradiction"
  else:
    return "neutral"

# %%
dev_labels = [map_to_num(x) for x in df_snli_mt_dev['labels'].to_list()]
df_snli_mt_dev['labels'] = dev_labels
df_snli_mt_dev["labels"] = df_snli_mt_dev["labels"].astype(int)

# %%
eval_labels = [map_to_num(x) for x in df_snli_mt_eval['labels'].to_list()]
df_snli_mt_eval['labels'] = eval_labels
df_snli_mt_eval["labels"] = df_snli_mt_eval["labels"].astype(int)

# %%
df_snli_mt_dev.head(10)
# Out:
#                                               text_a  \
# 0  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 1  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 2  Persuna fuq żiemel taqbeż minn fuq ajruplan im...
# 3                 Tfal jitbissmu u jxejru mal-kamera
# 4                 Tfal jitbissmu u jxejru mal-kamera
# 5                 Tfal jitbissmu u jxejru mal-kamera
# 6  Tifel qed jaqbeż fuq skateboard f’nofs pont aħ...
# 7  Tifel qed jaqbeż fuq skateboard f’nofs pont aħ...
# 8  Tifel qed jaqbeż fuq skateboard f’nofs pont aħ...
# 9  Raġel anzjan joqgħod bil-meraq tal-larinġ tieg...
#
#                                               text_b  labels
# 0  Persuna qed titħarreġ iż-żiemel tagħha għal ko...       1
# 1             Persuna tkun f'diner, tordna omelette.       2
# 2                    Persuna tkun barra, fuq żiemel.       0
# 3             Qed jitbissmu lejn il-ġenituri tagħhom       1
# 4                                 Hemm tfal preżenti       0
# 5                                 It-tfal qed iqarqu       2
# 6                    It-tifel jiskejkja mal-bankina.       2
# 7              It-tifel jagħmel trick skateboarding.       0
# 8           It-tifel qed jilbes tagħmir tas-sigurtà.       1
# 9  Raġel anzjan jixrob il-meraq tiegħu waqt li ji...       1

# %%
model_args = ClassificationArgs()
model_args.num_train_epochs = 4
model_args.learning_rate = 5e-5
model_args.train_batch_size = 4
model_args.gradient_accumulation_steps = 2
model_args.fp16 = True
model_args.use_multiprocessing = False
model_args.use_multiprocessing_for_evaluation = False
model_args.use_multiprocessed_decoding = False
model_args.overwrite_output_dir = True
model_args.reprocess_input_data = True
model_args.use_multiprocessing=False
model_args.wandb_project = 'dissertation'
# model_args.manual_seed = 4
model_args.max_seq_length = 512
model_args.evaluate_during_training = True
model_args.evaluate_during_training_steps = 50000
model_args.evaluate_during_training_verbose = True
model_args.save_eval_checkpoints = False
model_args.save_steps = 250000
model_args.output_dir = OUTPUT_PATH

# %%
model = ClassificationModel("bert", "MLRS/BERTu", num_labels=3, args=model_args, use_cuda=cuda_available)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at MLRS/BERTu and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score

def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average = 'macro')

def recall_multiclass(labels, preds):
    return recall_score(labels, preds, average = 'macro')

def precision_multiclass(labels, preds):
    return precision_score(labels, preds, average = 'macro')

# %%
model.train_model(df_snli_mt_dev,eval_df=df_snli_mt_eval, precision=precision_multiclass, f1 = f1_multiclass, recall=recall_multiclass,  acc=accuracy_score)

# %%
result, model_outputs, wrong_predictions = model.eval_model(
    df_snli_mt_eval
)
# Out:
# Running Evaluation:   0%|          | 0/1228 [00:00<?, ?it/s]
# Finishing last run (ID:ude7m9ze) before initializing another...
# VBox(children=(Label(value='0.026 MB of 0.035 MB uploaded\r'), FloatProgress(value=0.7323070286592435, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▄▄▅▆▂▂▂▁▃▄▃▄▂▃▃▂▁▃▂▄▃▃▃▂▂▂▄▁▂▂▁▁▁▂▃▃▁▂▁</td></tr><tr><td>acc</td><td>▁▅█▇▇</td></tr><tr><td>eval_loss</td><td>▃▁▁▄█</td></tr><tr><td>f1</td><td>▁▅█▇▇</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▂▄████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▅█▇▇</td></tr><tr><td>precision</td><td>▁▅█▇▇</td></tr><tr><td>recall</td><td>▁▅█▇▇</td></tr><tr><td>train_loss</td><td>█▁▂▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.09474</td></tr><tr><td>acc</td><td>0.85882</td></tr><tr><td>eval_loss</td><td>0.53201</td></tr><tr><td>f1</td><td>0.85857</td></tr><tr><td>global_step</td><td>42920</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.78823</td></tr><tr><td>precision</td><td>0.85858</td></tr><tr><td>recall</td><td>0.85861</td></tr><tr><td>train_loss</td><td>0.00584</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">floral-smoke-17</strong> at: <a href='https://wandb.ai/darmanin-matt/dissertation/runs/ude7m9ze' target="_blank">https://wandb.ai/darmanin-matt/dissertation/runs/ude7m9ze</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231225_121059-ude7m9ze/logs</code>
# Successfully finished last run (ID:ude7m9ze). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112041947328382, max=1.0…
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/home/nli/wandb/run-20231225_192751-fuif2qox</code>
# Syncing run <strong><a href='https://wandb.ai/darmanin-matt/dissertation/runs/fuif2qox' target="_blank">ethereal-mountain-18</a></strong> to <a href='https://wandb.ai/darmanin-matt/dissertation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/darmanin-matt/dissertation' target="_blank">https://wandb.ai/darmanin-matt/dissertation</a>
#  View run at <a href='https://wandb.ai/darmanin-matt/dissertation/runs/fuif2qox' target="_blank">https://wandb.ai/darmanin-matt/dissertation/runs/fuif2qox</a>

# %%
print("Accuracy: " + str(100*(1-len(wrong_predictions)/len(model_outputs))) + "%")
# Out:
# Accuracy: 85.88151465798046%

# %%
predictions, raw_outputs = model.predict(
    [
        [
            "Tifel jilgħab bil-ballun f'nofs ta' triq",
            "Tifel rieqed fis-sodda",
        ]
    ]
)
map_to_label(predictions[0])
