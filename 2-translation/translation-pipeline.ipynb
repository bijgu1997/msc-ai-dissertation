# %% [markdown]
# # Data Translation Pipeline
#
# ## Translation

# %%
# !pip install --upgrade pip
# !pip install requests --upgrade
import requests
import getpass
import pandas as pd
import os
import json
import time
from functools import lru_cache
pd.set_option('display.max_colwidth', None)

# %%
PREPROC_CSV_PATH = '/content/drive/MyDrive/Dissertation/data/preproc_csv'
TRANS_TXT_PATH = '/content/drive/MyDrive/Dissertation/data/trans_txt'
TRANS_CSV_PATH = '/content/drive/MyDrive/Dissertation/data/trans_csv'

# %%
df_snli_dev = pd.read_csv(os.path.join(PREPROC_CSV_PATH,'df_snli_dev.csv'), delimiter=";")
df_snli_train = pd.read_csv(os.path.join(PREPROC_CSV_PATH,'df_snli_train.csv'), delimiter=";")
df_snli_test = pd.read_csv(os.path.join(PREPROC_CSV_PATH,'df_snli_test.csv'), delimiter=";")
df_mnli_dev = pd.read_csv(os.path.join(PREPROC_CSV_PATH,'df_mnli_dev.csv'), delimiter=";")
df_mnli_train = pd.read_csv(os.path.join(PREPROC_CSV_PATH,'df_mnli_train.csv'), delimiter=";")

# %%
snli_dev_premise = df_snli_dev['premise'].tolist()
snli_train_premise = df_snli_train['premise'].tolist()
snli_test_premise = df_snli_test['premise'].tolist()
mnli_dev_premise = df_mnli_dev['premise'].tolist()
mnli_train_premise = df_mnli_train['premise'].tolist()
snli_dev_hypothesis = df_snli_dev['hypothesis'].tolist()
snli_train_hypothesis = df_snli_train['hypothesis'].tolist()
snli_test_hypothesis = df_snli_test['hypothesis'].tolist()
mnli_dev_hypothesis = df_mnli_dev['hypothesis'].tolist()
mnli_train_hypothesis = df_mnli_train['hypothesis'].tolist()

# %%
print(f"snli_dev_premise [{len(snli_dev_premise)}]")
print(f"snli_train_premise [{len(snli_train_premise)}]")
print(f"snli_test_premise [{len(snli_test_premise)}]")
print(f"mnli_dev_premise [{len(mnli_dev_premise)}]")
print(f"mnli_train_premise [{len(mnli_train_premise)}]")
print(f"snli_dev_hypothesis [{len(snli_dev_hypothesis)}]")
print(f"snli_train_hypothesis [{len(snli_train_hypothesis)}]")
print(f"snli_test_hypothesis [{len(snli_test_hypothesis)}]")
print(f"mnli_dev_hypothesis [{len(mnli_dev_hypothesis)}]")
print(f"mnli_train_hypothesis [{len(mnli_train_hypothesis)}]")
# Out:
# snli_dev_premise [9842]
# snli_train_premise [549361]
# snli_test_premise [9824]
# mnli_dev_premise [9815]
# mnli_train_premise [392659]
# snli_dev_hypothesis [9842]
# snli_train_hypothesis [549361]
# snli_test_hypothesis [9824]
# mnli_dev_hypothesis [9815]
# mnli_train_hypothesis [392659]

# %%
# Get Current progress of file
def get_progress(filepath):
  try:
    with open(os.path.join(TRANS_TXT_PATH,filepath),'r') as current_file:
      num_lines = len(current_file.readlines())
      return num_lines
  except:
    return 0

# Flush the buffer to the file
def write_list_to_file(list_to_write, out_filepath):
  with open(out_filepath, 'a') as file:
    file.writelines([str(x)+"\n" for x in list_to_write])

# Call the TranslatePlus API
@lru_cache(maxsize=5)
def translate_api(session, text, retry = True):
  translate_url = "https://api.translateplus.io/v1/translate"
  header = {"X-API-KEY":"a22eb1566341478d30276ee39cccbe319ba454d1"}
  json_obj = {
    "text": text,
    "source": "en",
    "target": "mt"
  }

  try:
    response = session.post(translate_url, json=json_obj, headers=header).json()
    result = response['translations']['translation']
  except:
    if retry:
      time.sleep(1)
      result = translate_api(session, text, False)
    else:
      result = f"COULD NOT TRANSLATE: [{text}]"
  return result

# Translate and flush buffer
def buffer_translate(input_list, buffer_size, out_filepath):
  total_sentences = len(input_list)
  buffers_flushed = 0
  session = requests.Session()
  buffer_list = []

  for sentence in input_list:
    buffer_list.append(translate_api(session, sentence))
    if len(buffer_list) >= buffer_size:
      write_list_to_file(buffer_list, out_filepath)
      buffer_list.clear()
      buffers_flushed += 1
      print(out_filepath + ": " + str(int((100*buffers_flushed*buffer_size)/total_sentences)) + "% complete")
  else:
    write_list_to_file(buffer_list, out_filepath)

# %%
prog_snli_dev_premise = get_progress('snli_dev_premise.txt')
prog_snli_train_premise = get_progress('snli_train_premise.txt')
prog_snli_test_premise = get_progress('snli_test_premise.txt')
prog_mnli_dev_premise = get_progress('mnli_dev_premise.txt')
prog_mnli_train_premise = get_progress('mnli_train_premise.txt')
prog_snli_dev_hypothesis = get_progress('snli_dev_hypothesis.txt')
prog_snli_train_hypothesis = get_progress('snli_train_hypothesis.txt')
prog_snli_test_hypothesis = get_progress('snli_test_hypothesis.txt')
prog_mnli_dev_hypothesis = get_progress('mnli_dev_hypothesis.txt')
prog_mnli_train_hypothesis = get_progress('mnli_train_hypothesis.txt')

# %%
buffer_translate(snli_dev_premise[prog_snli_dev_premise:], 500, os.path.join(TRANS_TXT_PATH,'snli_dev_premise.txt'))
buffer_translate(snli_train_premise[prog_snli_train_premise:], 500, os.path.join(TRANS_TXT_PATH,'snli_train_premise.txt'))
buffer_translate(snli_test_premise[prog_snli_test_premise:], 500, os.path.join(TRANS_TXT_PATH,'snli_test_premise.txt'))
buffer_translate(mnli_dev_premise[prog_mnli_dev_premise:], 500, os.path.join(TRANS_TXT_PATH,'mnli_dev_premise.txt'))
buffer_translate(mnli_train_premise[prog_mnli_train_premise:], 500, os.path.join(TRANS_TXT_PATH,'mnli_train_premise.txt'))
buffer_translate(snli_dev_hypothesis[prog_snli_dev_hypothesis:], 500, os.path.join(TRANS_TXT_PATH,'snli_dev_hypothesis.txt'))
buffer_translate(snli_train_hypothesis[prog_snli_train_hypothesis:], 500, os.path.join(TRANS_TXT_PATH,'snli_train_hypothesis.txt'))
buffer_translate(snli_test_hypothesis[prog_snli_test_hypothesis:], 500, os.path.join(TRANS_TXT_PATH,'snli_test_hypothesis.txt'))
buffer_translate(mnli_dev_hypothesis[prog_mnli_dev_hypothesis:], 500, os.path.join(TRANS_TXT_PATH,'mnli_dev_hypothesis.txt'))
buffer_translate(mnli_train_hypothesis[prog_mnli_train_hypothesis:], 500, os.path.join(TRANS_TXT_PATH,'mnli_train_hypothesis.txt'))

# %%
def get_list_from_file(filepath):
  with open(os.path.join(TRANS_TXT_PATH,filepath),'r') as current_file:
    out_list = [x.strip("\n") for x in current_file.readlines()]
    return out_list

# %%
snli_dev_premise_trans = get_list_from_file('snli_dev_premise.txt')
snli_train_premise_trans = get_list_from_file('snli_train_premise.txt')
snli_test_premise_trans = get_list_from_file('snli_test_premise.txt')
mnli_dev_premise_trans = get_list_from_file('mnli_dev_premise.txt')
mnli_train_premise_trans = get_list_from_file('mnli_train_premise.txt')
snli_dev_hypothesis_trans = get_list_from_file('snli_dev_hypothesis.txt')
snli_train_hypothesis_trans = get_list_from_file('snli_train_hypothesis.txt')
snli_test_hypothesis_trans = get_list_from_file('snli_test_hypothesis.txt')
mnli_dev_hypothesis_trans = get_list_from_file('mnli_dev_hypothesis.txt')
mnli_train_hypothesis_trans = get_list_from_file('mnli_train_hypothesis.txt')

# %%
df_snli_dev['premise'] = snli_dev_premise_trans
df_snli_dev['hypothesis'] = snli_dev_hypothesis_trans
df_snli_train['premise'] = snli_train_premise_trans
df_snli_train['hypothesis'] = snli_train_hypothesis_trans
df_snli_test['premise'] = snli_test_premise_trans
df_snli_test['hypothesis'] = snli_test_hypothesis_trans
df_mnli_dev['premise'] = mnli_dev_premise_trans
df_mnli_dev['hypothesis'] = mnli_dev_hypothesis_trans
df_mnli_train['premise'] = mnli_train_premise_trans
df_mnli_train['hypothesis'] = mnli_train_hypothesis_trans

# %%
df_snli_dev.to_csv(os.path.join(TRANS_CSV_PATH, 'df_snli_dev.csv'), encoding='utf-8',sep=';')
df_snli_train.to_csv(os.path.join(TRANS_CSV_PATH, 'df_snli_train.csv'), encoding='utf-8',sep=';')
df_snli_test.to_csv(os.path.join(TRANS_CSV_PATH, 'df_snli_test.csv'), encoding='utf-8',sep=';')
df_mnli_dev.to_csv(os.path.join(TRANS_CSV_PATH, 'df_mnli_dev.csv'), encoding='utf-8',sep=';')
df_mnli_train.to_csv(os.path.join(TRANS_CSV_PATH, 'df_mnli_train.csv'), encoding='utf-8',sep=';')

# %%
df_snli_merged = pd.concat([df_snli_dev, df_snli_test, df_snli_train])
df_mnli_merged = pd.concat([df_mnli_dev, df_mnli_train])

# %%
df_snli_merged.drop(columns='Unnamed: 0', inplace=True)
df_mnli_merged.drop(columns='Unnamed: 0', inplace=True)

# %%
df_snli_merged.head(20)
# Out:
#                                                                                                                                                    premise  \
# 0                                                                                               Żewġ nisa qed iħaddnu waqt li jżommu pakketti biex imorru.
# 1                                                                                               Żewġ nisa qed iħaddnu waqt li jżommu pakketti biex imorru.
# 2                                                                                               Żewġ nisa qed iħaddnu waqt li jżommu pakketti biex imorru.
# 3   Żewġt itfal żgħar bil-flokkijiet blu, wieħed bin-numru 9 u wieħed bin-numru 2 qegħdin fuq tarġien tal-injam f’kamra tal-banju u jaħslu idejhom f’sink.
# 4   Żewġt itfal żgħar bil-flokkijiet blu, wieħed bin-numru 9 u wieħed bin-numru 2 qegħdin fuq tarġien tal-injam f’kamra tal-banju u jaħslu idejhom f’sink.
# 5   Żewġt itfal żgħar bil-flokkijiet blu, wieħed bin-numru 9 u wieħed bin-numru 2 qegħdin fuq tarġien tal-injam f’kamra tal-banju u jaħslu idejhom f’sink.
# 6                                                        Raġel ibigħ doughnuts lil klijent waqt avveniment ta’ wirja dinjija li saret fil-belt ta’ Angeles
# 7                                                        Raġel ibigħ doughnuts lil klijent waqt avveniment ta’ wirja dinjija li saret fil-belt ta’ Angeles
# 8                                                        Raġel ibigħ doughnuts lil klijent waqt avveniment ta’ wirja dinjija li saret fil-belt ta’ Angeles
# 9                                       Żewġ subien ta’ timijiet opposti jilagħbu l-futbol, ​​filwaqt li lebsin uniformijiet ta’ protezzjoni sħiħa u elmi.
# 10                                      Żewġ subien ta’ timijiet opposti jilagħbu l-futbol, ​​filwaqt li lebsin uniformijiet ta’ protezzjoni sħiħa u elmi.
# 11                                      Żewġ subien ta’ timijiet opposti jilagħbu l-futbol, ​​filwaqt li lebsin uniformijiet ta’ protezzjoni sħiħa u elmi.
# 12                                                                  Raġel bi qmis blu wieqaf quddiem struttura qisha garaxx miżbugħa b’disinji ġeometriċi.
# 13                                                                  Raġel bi qmis blu wieqaf quddiem struttura qisha garaxx miżbugħa b’disinji ġeometriċi.
# 14                                                                  Raġel bi qmis blu wieqaf quddiem struttura qisha garaxx miżbugħa b’disinji ġeometriċi.
# 15                                       Taħt sema blu bi sħab abjad, tifel jilħaq biex imiss l-iskrun ta’ ajruplan wieqaf ipparkjat fuq għalqa tal-ħaxix.
# 16                                       Taħt sema blu bi sħab abjad, tifel jilħaq biex imiss l-iskrun ta’ ajruplan wieqaf ipparkjat fuq għalqa tal-ħaxix.
# 17                                       Taħt sema blu bi sħab abjad, tifel jilħaq biex imiss l-iskrun ta’ ajruplan wieqaf ipparkjat fuq għalqa tal-ħaxix.
# 18                                                                              Mara qed tagħmel cartwheel waqt li tilbes bikini fir-ramel ħdejn il-bajja.
# 19                                                                              Mara qed tagħmel cartwheel waqt li tilbes bikini fir-ramel ħdejn il-bajja.
#
#                                                                                                       hypothesis  \
# 0           Is-sorijiet qed jgħannqu addio waqt li jżommu pakketti biex imorru wara li jkunu għadhom kif jieklu.
# 1                                                                                 Żewġ nisa qed iżommu pakketti.
# 2                                                                             L-irġiel qed jiġġieldu barra deli.
# 3                                                            Żewġt itfal bil-flokkijiet numerati jaħslu idejhom.
# 4                                                             Żewġt itfal waqt logħba tal-ballun jaħslu idejhom.
# 5                                                                   Żewġt itfal bil-ġkieket jimxu lejn l-iskola.
# 6                                                               Mara tixrob il-kafè tagħha f'kafetterija żgħira.
# 7   Raġel ibigħ doughnuts lil klijent waqt avveniment ta’ wirja dinjija waqt li n-nies jistennew fil-kju warajh.
# 8                                                                            Raġel ibiegħ doughnuts lil klijent.
# 9                                                                                         subien jilagħbu futbol
# 10                                                                                     kelb jiekol minn skutella
# 11                                                                                 subien li jiskurjaw touchdown
# 12                                                                            Raġel qed iżebgħa mill-ġdid garaxx
# 13                                                                                    Raġel ikun liebes qmis blu
# 14                                                                                       Raġel liebes qmis sewda
# 15                                                            Tifel qed jilħaq biex imiss l-iskrun ta’ ajruplan.
# 16                                                            Tifel qed jilħaq biex imiss l-iskrun mill-kurżità.
# 17                                                                                 Tifel qed jilgħab bil-ballun.
# 18                                                                                   Mara qed tagħmel cartwheel.
# 19                                                                               Mara qed tirranġa d-dar tagħha.
#
#    classification
# 0         neutral
# 1      entailment
# 2   contradiction
# 3      entailment
# 4         neutral
# 5   contradiction
# 6   contradiction
# 7         neutral
# 8      entailment
# 9      entailment
# 10  contradiction
# 11        neutral
# 12        neutral
# 13     entailment
# 14  contradiction
# 15     entailment
# 16        neutral
# 17  contradiction
# 18     entailment
# 19  contradiction

# %%
df_snli_merged.tail(50)
# Out:
#                                                                                             premise  \
# 549311                        Diversi adulti qed jieħdu ħsieb lil uliedhom barra f’ġurnata xemxija.
# 549312                        Diversi adulti qed jieħdu ħsieb lil uliedhom barra f’ġurnata xemxija.
# 549313  Grupp ta’ tfal, subien u bniet, lebsin libsa tal-kor blu qegħdin bilwieqfa quddiem udjenza.
# 549314  Grupp ta’ tfal, subien u bniet, lebsin libsa tal-kor blu qegħdin bilwieqfa quddiem udjenza.
# 549315  Grupp ta’ tfal, subien u bniet, lebsin libsa tal-kor blu qegħdin bilwieqfa quddiem udjenza.
# 549316               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549317               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549318               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549319               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549320               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549321               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549322               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549323               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549324               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549325               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549326               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549327               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549328               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549329               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549330               Grupp ta’ tfal żgħar lebsin libsa blu qegħdin quddiem folla b’idejhom maħżuna.
# 549331                                          Żewġt irġiel weqfin barra lebsin ġkieket u brieret.
# 549332                                          Żewġt irġiel weqfin barra lebsin ġkieket u brieret.
# 549333                                          Żewġt irġiel weqfin barra lebsin ġkieket u brieret.
# 549334                                  Żewġt irġiel lebsin ġkieket u kpiepel qegħdin fuq terrazzin
# 549335                                  Żewġt irġiel lebsin ġkieket u kpiepel qegħdin fuq terrazzin
# 549336                                  Żewġt irġiel lebsin ġkieket u kpiepel qegħdin fuq terrazzin
# 549337                                    Erbat itfal qegħdin bilwieqfa biex jippożaw għal ritratt.
# 549338                                    Erbat itfal qegħdin bilwieqfa biex jippożaw għal ritratt.
# 549339                                    Erbat itfal qegħdin bilwieqfa biex jippożaw għal ritratt.
# 549340                                             Surfer iħares warajh biex jara l-mewġa li jmiss.
# 549341                                             Surfer iħares warajh biex jara l-mewġa li jmiss.
# 549342                                             Surfer iħares warajh biex jara l-mewġa li jmiss.
# 549343                      Grupp ta’ nies bil-salvataġġ oranġjo qed jitilgħu fuq ċattri fl-Artiku.
# 549344                      Grupp ta’ nies bil-salvataġġ oranġjo qed jitilgħu fuq ċattri fl-Artiku.
# 549345                      Grupp ta’ nies bil-salvataġġ oranġjo qed jitilgħu fuq ċattri fl-Artiku.
# 549346                             Grupp ta’ erbat itfal bilwieqfa quddiem statwa ta’ annimal kbir.
# 549347                             Grupp ta’ erbat itfal bilwieqfa quddiem statwa ta’ annimal kbir.
# 549348                             Grupp ta’ erbat itfal bilwieqfa quddiem statwa ta’ annimal kbir.
# 549349                                                 tifel jagħmel tricks fuq skateboard fuq pont
# 549350                                                 tifel jagħmel tricks fuq skateboard fuq pont
# 549351                                                 tifel jagħmel tricks fuq skateboard fuq pont
# 549352                                                    Kelb b'għonq blu jilgħab il-ballun barra.
# 549353                                                    Kelb b'għonq blu jilgħab il-ballun barra.
# 549354                                                    Kelb b'għonq blu jilgħab il-ballun barra.
# 549355                                                             Erbat itfal maħmuġin u mikxufin.
# 549356                                                             Erbat itfal maħmuġin u mikxufin.
# 549357                                                             Erbat itfal maħmuġin u mikxufin.
# 549358                                       Raġel qed jagħmel surfing b'bodysuit f'ilma blu sabiħ.
# 549359                                       Raġel qed jagħmel surfing b'bodysuit f'ilma blu sabiħ.
# 549360                                       Raġel qed jagħmel surfing b'bodysuit f'ilma blu sabiħ.
#
#                                                                        hypothesis  \
# 549311                                                 L-adulti għandhom it-tfal.
# 549312                                                In-nies qed jagħmlu picnic.
# 549313                                żewġ subien jippritkaw lil grupp ta’ nagħaġ
# 549314                                       isir prestazzjoni tal-kor tal-knisja
# 549315                         xi tfal bil-libes tal-kor joqogħdu ħdejn nies oħra
# 549316                                                        It-tfal qed jorqdu.
# 549317                                                It-tfal qegħdin fil-knisja.
# 549318                                       Grupp ta’ adulti jkantaw lill-folla.
# 549319                                                  it-tfal huma d-dar jorqdu
# 549320                                                          xi tfal bilwieqfa
# 549321                         Kor ta’ tfal żgħar waslu biex iwettqu għall-folla.
# 549322                                                       It-tfal qed ikantaw.
# 549323                                         Grupp ta’ tfal jilagħbu tag barra.
# 549324                                                                Jagħmel kor
# 549325                                             Il-folla tista’ tara lit-tfal.
# 549326                           Grupp ta’ tfal bilwieqfa quddiem grupp ta’ nies.
# 549327                                                          it-tfal huma aħwa
# 549328                                                  It-tfal qed iżommu idejn.
# 549329                                     Grupp ta’ tfal bilwieqfa quddiem folla
# 549330                                                        It-tfal qed jgħumu.
# 549331                                                Żewġt irġiel jinsabu barra.
# 549332                                                   Żewġt irġiel qed jgħumu.
# 549333                                Żewġt irġiel qegħdin f’logħba tal-baseball.
# 549334                                          2 irġiel lebsin tajjeb huma barra
# 549335                                                          3 nisa huma barra
# 549336                                            2 irġiel bil-ilbiesi huma barra
# 549337                                     Erbat itfal qed jippożaw għal ritratt.
# 549338                 Erba’ adulti qegħdin bilwieqfa biex jippożaw għal ritratt.
# 549339                      Xi tfal qegħdin bilwieqfa biex jippożaw għal ritratt.
# 549340                                 A surfer jibqa attent għall-madwar tiegħu.
# 549341                                   Surfer jaqta’ fil-mewġa li jmiss tiegħu.
# 549342                           Surfer wieqaf fuq il-bajja ħdejn il-bord tiegħu.
# 549343                                    Il-flokkijiet tas-salvataġġ huma ħomor.
# 549344                                 Il-flokkijiet tas-salvataġġ jaħdmu tajjeb.
# 549345                                                                 Hemm nies.
# 549346                                                         it-tfal huma suwed
# 549347                                                    it-tfal huma bilqiegħda
# 549348                                                      erbat itfal bilwieqfa
# 549349                                                   tifel huwa skateboarding
# 549350                                                        tifel qiegħed ġewwa
# 549351                               tifel qiegħed fuq il-pont tal-bieb tad-deheb
# 549352                                                  kelb qiegħed fuq is-sufan
# 549353                                                            kelb huwa barra
# 549354                                                     kelb qed isegwi ballun
# 549355                                      erbat itfal għandhom saqajn maħmuġin.
# 549356                   erbat itfal rebħu premjijiet għal 'saqajn l-aktar nodfa'
# 549357  erbat itfal bla dar insterqu ż-żraben, u għalhekk saqajhom huma maħmuġin.
# 549358             Raġel bil-bodysuit qed jikkompeti f'kompetizzjoni tas-surfing.
# 549359                     Raġel b'libsa tan-negozju sejjer għal laqgħa tal-bord.
# 549360                      Fuq l-ilma blu sabiħ hemm raġel bil-bodysuit surfing.
#
#        classification
# 549311     entailment
# 549312        neutral
# 549313  contradiction
# 549314        neutral
# 549315     entailment
# 549316  contradiction
# 549317        neutral
# 549318  contradiction
# 549319  contradiction
# 549320     entailment
# 549321        neutral
# 549322        neutral
# 549323  contradiction
# 549324        neutral
# 549325     entailment
# 549326     entailment
# 549327        neutral
# 549328     entailment
# 549329     entailment
# 549330  contradiction
# 549331     entailment
# 549332  contradiction
# 549333        neutral
# 549334     entailment
# 549335  contradiction
# 549336        neutral
# 549337     entailment
# 549338  contradiction
# 549339        neutral
# 549340     entailment
# 549341        neutral
# 549342  contradiction
# 549343  contradiction
# 549344        neutral
# 549345     entailment
# 549346        neutral
# 549347  contradiction
# 549348     entailment
# 549349     entailment
# 549350  contradiction
# 549351        neutral
# 549352  contradiction
# 549353     entailment
# 549354        neutral
# 549355     entailment
# 549356  contradiction
# 549357        neutral
# 549358        neutral
# 549359  contradiction
# 549360     entailment

# %%
df_mnli_merged.head(5)
# Out:
#                                                                                                                                        premise  \
# 0                                                                                                  Id-drittijiet il-ġodda huma sbieħ biżżejjed
# 1                      Dan is-sit jinkludi lista tar-rebbieħa kollha tal-premjijiet u database ta’ tiftix ta’ artikli tal-Eżekuttiv tal-Gvern.
# 2                     uh ma nafx għandi emozzjonijiet imħallta dwaru uh kultant jogħġobni imma fl-istess ħin inħobb nara lil xi ħadd iħabbatlu
# 3  iva naħseb li r-restorant favorit tiegħi dejjem kien l-eqreb li taf l-eqreb sakemm ikun jissodisfa l-kriterji minimi li taf ta' ikel tajjeb
# 4                                                                                                             ma nafx um tagħmel ħafna kampeġġ
#
#                                                                                  hypothesis  \
# 0                                           Kulħadd verament jħobb l-aktar benefiċċji ġodda
# 1  L-artikoli tal-Eżekuttiv tal-Gvern li jinsabu fuq il-websajt ma jistgħux jiġu mfittxija.
# 2      Jogħġobni fil-biċċa l-kbira tiegħu, iżda xorta nieħu gost nara lil xi ħadd isawwatu.
# 3      Ir-ristoranti favoriti tiegħi huma dejjem mill-inqas mitt mil bogħod mid-dar tiegħi.
# 4                                                                           Naf eżattament.
#
#   classification
# 0        neutral
# 1  contradiction
# 2     entailment
# 3  contradiction
# 4  contradiction

# %%
df_mnli_merged.tail(5)
# Out:
#                                                                                                                                                                                                                                                                             premise  \
# 392654                                                                                                                                                                                                                       B'mod ċar, California tista' - u trid - tagħmel aħjar.
# 392655                                                                                                                                  Darba kienet meqjusa bħala l-isbaħ triq fl-Ewropa, dikjarazzjoni li diffiċli tifhem illum peress li tant mill-bini oriġinali ġie sostitwit.
# 392656                                                                                                                                                                                     Il-houseboats huma tradizzjoni preservata b'mod sabiħ tal-aqwa żmien tar-Raj Brittaniku.
# 392657                                                                                               L-obituaries fakkru b’mod qalb id-dibattiti tiegħu fuq l-arja u żewġ tislima b’riżerva kbira mar-reviżur sħabu Roger Ebert fuq il-programm televiżiv sindakat eponimu tagħhom.
# 392658  f'dik l-oħra taf uh li għandi nagħmilha jew dik jew sempliċement biex naħseb biex nagħmilha ratha milli jkolli xi ħadd jgħidlu biex jagħmel dan naf li kienet ħaġa kbira fid-dar tagħna għal żmien twil kienet li jekk ridt tiegħi ir-raġel biex jagħmel xi ħaġa biex jgħin
#
#                                                                                                 hypothesis  \
# 392654                                                                 California ma tistax tagħmel aħjar.
# 392655                 Allura ħafna mill-bini oriġinali kienu ġew sostitwiti minn ħwienet tal-konvenjenza.
# 392656           It-tradizzjoni tal-houseboats oriġinat waqt li l-British Raj kien għadu għaddej b'saħħtu.
# 392657  L-obituaries kienu sbieħ u miktuba in natura dwar il-kisbiet tiegħu fl-industrija tad-divertiment.
# 392658   Dan l-aħħar żewġi tant kien xogħol żżejjed li ma nistax nistaqsih biex jagħmel ħafna madwar hawn.
#
#        classification
# 392654  contradiction
# 392655        neutral
# 392656     entailment
# 392657        neutral
# 392658        neutral

# %%
df_mnli_merged.to_csv(os.path.join(TRANS_CSV_PATH, 'df_mnli_translated.csv'), encoding='utf-8',sep=';')
df_snli_merged.to_csv(os.path.join(TRANS_CSV_PATH, 'df_snli_translated.csv'), encoding='utf-8',sep=';')
